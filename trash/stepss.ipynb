# %% [markdown]
# #### kafka

# %% [markdown]
# - zookeeper-server-start.sh config/zookeeper.properties
# - kafka-server-start.sh config/server.properties

# %% [markdown]
# #### HDFS

# %% [markdown]
# - start-dfs.sh

# %% [markdown]
# #### KAFKA Producer

# %% [markdown]
# - python producer/coingecko_producer.py

# %% [markdown]
# #### 4. Spark Streaming Consumer

# %% [markdown]
# - spark-submit spark_consumer.py

# %% [markdown]
# #### Streamlit

# %% [markdown]
# - streamlit run streamlitapp.py

# %% [markdown]
# #### VERIFY DATA IS LANDING IN HDFS (LIVE CHECK)

# %% [markdown]
# - hdfs dfs -ls /crypto/prices

# %% [markdown]
# - inspect one
#    - hdfs dfs -du -h /crypto/prices
