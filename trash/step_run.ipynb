# %% [markdown]
# - cd ~/kafka

# %% [markdown]
# - (venv) ashik@ashik-HP-Laptop-14-dq2xxx:~/kafka$ bin/zookeeper-server-start.sh config/zookeeper.properties

# %% [markdown]
# ___

# %% [markdown]
# - cd ~/kafka
# - bin/kafka-server-start.sh config/server.properties

# %% [markdown]
# ___

# %% [markdown]
# ```bash
# cd ~/kafka
#
# bin/kafka-topics.sh \
#   --create \
#   --topic crypto_prices \
#   --bootstrap-server localhost:9092 \
#   --partitions 1 \
#   --replication-factor 1
# ```

# %% [markdown]
# - Verify:

# %% [markdown]
# - bin/kafka-topics.sh --list --bootstrap-server localhost:9092

# %% [markdown]
# ___

# %% [markdown]
# ##### TERMINAL 3 — START PYTHON PRODUCER
# - python producer/coingecko_producer.py

# %% [markdown]
# #### TERMINAL 4 — START SPARK CONSUMER

# %% [markdown]
# - export SPARK_HOME=~/spark
# - export PATH=$SPARK_HOME/bin:$PATH

# %% [markdown]
# ```bash
# cd ~/codes/Cc_Pipe
#
# spark-submit \
#   --packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.0 \
#   spark_kafka_consumer.py
# ```
